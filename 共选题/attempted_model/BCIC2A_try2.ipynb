# %% [markdown]
# ## 1) 设定环境并读取基本信息
# 解析 `dataset_info.json` 以动态获取数据特征（通道数、采样点、类别等），消除硬编码。

# %%
import json
import h5py
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import os
import copy
from torch.utils.data import DataLoader

# 假设自定义的 Dataset 路径已正确配置
from course_project.TEST_DATASET import TrainDataset, TestDataset

DATA_NAME = "BCIC2A" 
DATA_INFO_PATH = f"course_project/{DATA_NAME}/dataset_info.json"
INDEX_PATH_TRAIN = f"course_project/{DATA_NAME}/train.h5"
INDEX_PATH_VAL = f"course_project/{DATA_NAME}/val.h5"
INDEX_PATH_TEST = f"course_project/{DATA_NAME}/test_x_only.h5"

with open(DATA_INFO_PATH, "r", encoding="utf-8") as f:
    info = json.load(f)

num_labels = info["dataset"]["num_labels"]
category_list = info["dataset"]["category_list"]
channels = info["dataset"]["channels"]
target_sampling_rate = info["processing"]["target_sampling_rate"]
window_sec = info["processing"]["window_sec"]

print("=== Dataset Information ===")
print("Number of Labels:", num_labels)
print("Categories:", category_list)
print("Channels (count):", len(channels))
print("Target Sampling Rate (Hz):", target_sampling_rate)
print("Window Size (sec):", window_sec)

# 动态确定输入特征维度
time_points = int(target_sampling_rate * window_sec)
num_channels = len(channels)
num_classes = num_labels
# Out:
# === Dataset Information ===
# Number of Labels: 4
# Categories: ['left', 'right', 'foot', 'tongue']
# Channels (count): 22
# Target Sampling Rate (Hz): 200.0
# Window Size (sec): 1.0

# %% [markdown]
# ## 2) 检查数据形状

# %%
print("========== 检查训练集 (Train) ==========")
with h5py.File(INDEX_PATH_TRAIN, "r") as f:
    print("keys:", list(f.keys()))
    print("x dtype:", f["X"].dtype)
    print("x shape:", f["X"].shape)
    print("y dtype:", f["y"].dtype)
    print("y shape:", f["y"].shape)
    y = f["y"][()]
    print("unique:", np.unique(y))
    
print("\n========== 检查验证集 (Validation) ==========")
with h5py.File(INDEX_PATH_VAL, "r") as f:
    print("keys:", list(f.keys()))
    print("x dtype:", f["X"].dtype)
    print("x shape:", f["X"].shape)
    print("y dtype:", f["y"].dtype)
    print("y shape:", f["y"].shape)
    y = f["y"][()]
    print("unique:", np.unique(y))
    
print("\n========== 检查测试集 (Test - X only) ==========")
with h5py.File(INDEX_PATH_TEST, "r") as f:
    print("keys:", list(f.keys()))
    print("x dtype:", f["X"].dtype)
    print("x shape:", f["X"].shape)
# Out:
# ========== 检查训练集 (Train) ==========
# keys: ['X', 'y']
# x dtype: float32
# x shape: (720, 22, 800)
# y dtype: int64
# y shape: (720,)
# unique: [0 1 2 3]
#
# ========== 检查验证集 (Validation) ==========
# keys: ['X', 'y']
# x dtype: float32
# x shape: (360, 22, 800)
# y dtype: int64
# y shape: (360,)
# unique: [0 1 2 3]
#
# ========== 检查测试集 (Test - X only) ==========
# keys: ['X']
# x dtype: float32
# x shape: (360, 22, 800)

# %% [markdown]
# ## 3) 定义模型
# 这里预留了模型替换的空间。

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class TCNDilatedBlock(nn.Module):
    """
    TCN (Temporal Convolutional Network) 中的膨胀卷积残差块
    通过不同的膨胀率(Dilation)获得指数级扩大的感受野，专门用于捕获长程时序依赖
    """
    def __init__(self, channels, kernel_size=3, dilation=1, dropout=0.3):
        super(TCNDilatedBlock, self).__init__()
        # 为了保证卷积后序列长度不变 (same padding)
        padding = (kernel_size - 1) * dilation // 2 
        
        self.conv1 = nn.Conv1d(channels, channels, kernel_size, padding=padding, dilation=dilation, bias=False)
        self.bn1 = nn.BatchNorm1d(channels)
        self.dropout1 = nn.Dropout(dropout)
        
        self.conv2 = nn.Conv1d(channels, channels, kernel_size, padding=padding, dilation=dilation, bias=False)
        self.bn2 = nn.BatchNorm1d(channels)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x):
        residual = x
        out = F.elu(self.bn1(self.conv1(x)))
        out = self.dropout1(out)
        out = self.bn2(self.conv2(out))
        # 残差连接
        out = F.elu(out + residual)
        out = self.dropout2(out)
        return out


class ATCNet(nn.Module):
    """
    ATCNet: Attention-Based Temporal Convolutional Network
    架构流：局部空时CNN -> 多头自注意力(MHA) -> 多层膨胀TCN -> 全连接层
    """
    def __init__(self, input_channels, num_classes, time_points=200):
        super(ATCNet, self).__init__()
        
        # ==========================================
        # 1. CNN 块 (Conv Block)
        # ==========================================
        self.temporal_conv = nn.Conv2d(1, 16, kernel_size=(1, 31), padding=(0, 15), bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        
        self.spatial_conv = nn.Conv2d(16, 16, kernel_size=(input_channels, 1), bias=False)
        self.bn2 = nn.BatchNorm2d(16)
        
        # 时间维度池化，将高频信号降维
        self.pool = nn.AvgPool2d((1, 4))
        self.dropout_cnn = nn.Dropout(0.3)

        # 动态推导池化后的序列长度
        with torch.no_grad():
            dummy_x = torch.zeros(1, 1, input_channels, time_points)
            dummy_x = self.temporal_conv(dummy_x)
            dummy_x = self.spatial_conv(dummy_x)
            dummy_x = self.pool(dummy_x)
            # (Batch, Features, 1, Seq_len)
            _, d_model, _, seq_len = dummy_x.shape
            
        self.d_model = d_model  # 16维
        self.seq_len = seq_len

        # ==========================================
        # 2. 注意力块 (Attention Block)
        # ==========================================
        # 在整个时间序列上进行多头注意力机制，寻找最显著的时序片段
        self.attention = nn.MultiheadAttention(embed_dim=self.d_model, num_heads=2, dropout=0.3, batch_first=True)
        self.norm = nn.LayerNorm(self.d_model)

        # ==========================================
        # 3. 时间卷积网络 (TCN Block)
        # ==========================================
        # 级联多个 TCN 块，膨胀率呈指数增长 (1, 2, 4)
        self.tcn = nn.Sequential(
            TCNDilatedBlock(channels=self.d_model, kernel_size=3, dilation=1),
            TCNDilatedBlock(channels=self.d_model, kernel_size=3, dilation=2),
            TCNDilatedBlock(channels=self.d_model, kernel_size=3, dilation=4)
        )

        # ==========================================
        # 4. 分类器
        # ==========================================
        self.classifier = nn.Sequential(
            nn.Linear(self.d_model, 32),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        # x 输入: (B, C, T) -> (B, 1, C, T)
        x = x.unsqueeze(1)
        
        # --- 1. CNN Block ---
        x = self.temporal_conv(x)
        x = F.elu(self.bn1(x))
        x = self.spatial_conv(x)
        x = F.elu(self.bn2(x))
        x = self.pool(x)
        x = self.dropout_cnn(x)
        
        # 降维并转换通道以适配 Attention: (B, 16, 1, Seq) -> (B, Seq, 16)
        x = x.squeeze(2).permute(0, 2, 1)
        
        # --- 2. Attention Block ---
        # 注意力计算并使用残差连接
        attn_out, _ = self.attention(x, x, x)
        x = self.norm(x + attn_out)
        
        # 转换通道以适配 TCN (1D 卷积要求特征在中间维度): (B, Seq, 16) -> (B, 16, Seq)
        x = x.permute(0, 2, 1)
        
        # --- 3. TCN Block ---
        x = self.tcn(x)
        
        # --- 4. 聚合与分类 ---
        # 使用全局平均池化在时间维度上压缩: (B, 16, Seq) -> (B, 16)
        x = torch.mean(x, dim=2)
        logits = self.classifier(x)
        
        return logits

# %% [markdown]
# ## 4) 配置数据加载器、设备与优化器
# 添加了设备自适应检测（CUDA GPU / Apple MPS / CPU），并优化了超参数区域。

# %%
# -------------------------
# 超参数设定
# -------------------------
BATCH_SIZE = 64
EPOCHS = 200          # 增加总 Epoch 数，依靠早停来控制结束
LR = 1e-3
PATIENCE = 20        # 早停的耐心值（验证集持续多少轮不上升则停止）

# -------------------------
# 设定计算设备 (GPU / MPS / CPU)
# -------------------------
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# -------------------------
# 准备 DataLoader
# -------------------------
train_ds = TrainDataset(INDEX_PATH_TRAIN)
val_ds = TrainDataset(INDEX_PATH_VAL)   
test_ds = TestDataset(INDEX_PATH_TEST)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False)

# 新增： 动态获取真实的 time_points，彻底避免维度不匹配
sample_x, _ = train_ds[0]  
real_time_points = sample_x.shape[1] 

if real_time_points != time_points:
    print(f"检测到真实的采样点长度 (Time Points): {real_time_points}，与预设值 {time_points} 不一致")

# -------------------------
# 实例化模型、损失函数、优化器
# -------------------------
model = ATCNet(
    input_channels=num_channels,
    time_points=real_time_points,
    num_classes=num_classes
).to(device)

# [优化 1] 标签平滑 (Label Smoothing)：针对 BCI 噪声数据，防止模型过度自信
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

# [优化 2] 增加 Weight Decay：从原先的 1e-4 提升到 1e-3，强力抑制过拟合
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=1e-3)

# [优化 3] 余弦退火学习率调度器：让学习率平滑下降，解决验证集震荡问题
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-5)
# Out:
# Using device: cpu
# 检测到真实的采样点长度 (Time Points): 800，与预设值 200 不一致

# %% [markdown]
# ## 5) 模型训练与验证
# 实现了 **Early Stopping** 和 **Best Model 保存机制**。避免模型训练到最后已经严重过拟合。

# %%
# 用于记录曲线的数组
train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

best_val_acc = 0.0
best_model_weights = None
epochs_no_improve = 0
has_saved_model = False
best_model_path = None 

os.makedirs("model_checkpoints", exist_ok=True)

for epoch in range(EPOCHS):
    # ===== Train =====
    model.train()
    train_loss_sum = 0.0
    train_correct = 0  
    train_num = 0

    for data, label in train_loader:
        data, label = data.to(device), label.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, label)
        loss.backward()
        
        # [优化 4] 梯度裁剪：强行截断过大的梯度，防止 loss 突然炸裂跳跃
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()

        batch_size = label.size(0)
        train_loss_sum += loss.item() * batch_size
        train_num += batch_size

        train_pred = torch.argmax(output, dim=1)
        train_correct += (train_pred == label).sum().item()

    epoch_train_loss = train_loss_sum / train_num
    epoch_train_acc = train_correct / train_num  
    
    train_losses.append(epoch_train_loss)
    train_accuracies.append(epoch_train_acc)     

    # ===== Validation =====
    model.eval()
    val_loss_sum = 0.0
    val_correct = 0
    val_num = 0

    with torch.no_grad():
        for val_data, val_label in val_loader:
            val_data, val_label = val_data.to(device), val_label.to(device)
            
            val_output = model(val_data)
            val_loss = criterion(val_output, val_label)

            batch_size = val_label.size(0)
            val_loss_sum += val_loss.item() * batch_size
            val_num += batch_size

            val_pred = torch.argmax(val_output, dim=1)
            val_correct += (val_pred == val_label).sum().item()

    epoch_val_loss = val_loss_sum / val_num
    epoch_val_acc = val_correct / val_num

    val_losses.append(epoch_val_loss)
    val_accuracies.append(epoch_val_acc)

    # [优化关联] 学习率更新
    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    # 打印每轮训练结果 (加入了当前学习率显示)
    print(
        f"Epoch [{epoch+1:03d}/{EPOCHS}] | LR: {current_lr:.5f} | "
        f"Train Loss: {epoch_train_loss:.4f} | "
        f"Train Acc: {epoch_train_acc:.2%} | "
        f"Val Loss: {epoch_val_loss:.4f} | "
        f"Val Acc: {epoch_val_acc:.2%}"
    )

    # ===== 最佳模型保存与早停逻辑 =====
    if epoch_val_acc > best_val_acc:
        best_val_acc = epoch_val_acc
        epochs_no_improve = 0  # 重置耐心值
        
        best_model_weights = copy.deepcopy(model.state_dict())
        current_model_path = f"model_checkpoints/{DATA_NAME}_best_model_acc{best_val_acc * 100:.2f}.pth"
  
        # 删除旧权重，保存新权重
        if best_model_path and os.path.exists(best_model_path):
            os.remove(best_model_path)
        best_model_path = current_model_path
        torch.save(best_model_weights, best_model_path)
        has_saved_model = True
        print(f" ---> 出现更高的验证集准确率 ({best_val_acc:.2%})，已更新模型。")
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= PATIENCE:
            print(f"\nTriggered Early Stopping at Epoch {epoch+1}!")
            break

print("\n" + "-" * 40)
print(f"Final Best Val Accuracy: {best_val_acc:.2%}")

if has_saved_model:
    print(f"训练成功结束！最佳模型已保存至: {best_model_path}")
else:
    print("\n【提醒】训练结束但未保存模型！因为在第 10 个 Epoch 之后，准确率没有超越过前期，请调整代码。")
# Out:
# Epoch [001/200] | LR: 0.00100 | Train Loss: 1.4049 | Train Acc: 21.67% | Val Loss: 1.3910 | Val Acc: 27.22%
#  ---> 出现更高的验证集准确率 (27.22%)，已更新模型。
# Epoch [002/200] | LR: 0.00100 | Train Loss: 1.3919 | Train Acc: 25.69% | Val Loss: 1.3933 | Val Acc: 27.78%
#  ---> 出现更高的验证集准确率 (27.78%)，已更新模型。
# Epoch [003/200] | LR: 0.00100 | Train Loss: 1.3872 | Train Acc: 24.72% | Val Loss: 1.4226 | Val Acc: 25.00%
# Epoch [004/200] | LR: 0.00100 | Train Loss: 1.3858 | Train Acc: 26.67% | Val Loss: 1.4393 | Val Acc: 25.00%
# Epoch [005/200] | LR: 0.00100 | Train Loss: 1.3861 | Train Acc: 27.08% | Val Loss: 1.4360 | Val Acc: 26.11%
# Epoch [006/200] | LR: 0.00100 | Train Loss: 1.3751 | Train Acc: 28.47% | Val Loss: 1.4191 | Val Acc: 28.33%
#  ---> 出现更高的验证集准确率 (28.33%)，已更新模型。
# Epoch [007/200] | LR: 0.00100 | Train Loss: 1.3738 | Train Acc: 28.89% | Val Loss: 1.3798 | Val Acc: 29.72%
#  ---> 出现更高的验证集准确率 (29.72%)，已更新模型。
# Epoch [008/200] | LR: 0.00100 | Train Loss: 1.3718 | Train Acc: 30.00% | Val Loss: 1.3607 | Val Acc: 33.89%
#  ---> 出现更高的验证集准确率 (33.89%)，已更新模型。
# Epoch [009/200] | LR: 0.00100 | Train Loss: 1.3685 | Train Acc: 32.36% | Val Loss: 1.3923 | Val Acc: 32.50%
# Epoch [010/200] | LR: 0.00099 | Train Loss: 1.3663 | Train Acc: 31.25% | Val Loss: 1.3540 | Val Acc: 32.22%
# Epoch [011/200] | LR: 0.00099 | Train Loss: 1.3657 | Train Acc: 29.03% | Val Loss: 1.4105 | Val Acc: 29.72%
# Epoch [012/200] | LR: 0.00099 | Train Loss: 1.3582 | Train Acc: 32.08% | Val Loss: 1.3694 | Val Acc: 34.17%
#  ---> 出现更高的验证集准确率 (34.17%)，已更新模型。
# Epoch [013/200] | LR: 0.00099 | Train Loss: 1.3532 | Train Acc: 31.81% | Val Loss: 1.3666 | Val Acc: 31.67%
# Epoch [014/200] | LR: 0.00099 | Train Loss: 1.3453 | Train Acc: 33.61% | Val Loss: 1.4862 | Val Acc: 28.61%
# Epoch [015/200] | LR: 0.00099 | Train Loss: 1.3525 | Train Acc: 34.31% | Val Loss: 1.3596 | Val Acc: 31.39%
# Epoch [016/200] | LR: 0.00098 | Train Loss: 1.3402 | Train Acc: 32.64% | Val Loss: 1.3755 | Val Acc: 36.67%
#  ---> 出现更高的验证集准确率 (36.67%)，已更新模型。
# Epoch [017/200] | LR: 0.00098 | Train Loss: 1.3342 | Train Acc: 35.14% | Val Loss: 1.3698 | Val Acc: 33.61%
# Epoch [018/200] | LR: 0.00098 | Train Loss: 1.3193 | Train Acc: 36.94% | Val Loss: 1.3669 | Val Acc: 34.44%
# Epoch [019/200] | LR: 0.00098 | Train Loss: 1.3241 | Train Acc: 35.56% | Val Loss: 1.3677 | Val Acc: 37.22%
#  ---> 出现更高的验证集准确率 (37.22%)，已更新模型。
# Epoch [020/200] | LR: 0.00098 | Train Loss: 1.3221 | Train Acc: 34.58% | Val Loss: 1.4637 | Val Acc: 33.33%
# Epoch [021/200] | LR: 0.00097 | Train Loss: 1.3300 | Train Acc: 34.58% | Val Loss: 1.3639 | Val Acc: 34.72%
# Epoch [022/200] | LR: 0.00097 | Train Loss: 1.3058 | Train Acc: 38.61% | Val Loss: 1.4066 | Val Acc: 35.83%
# Epoch [023/200] | LR: 0.00097 | Train Loss: 1.2996 | Train Acc: 38.89% | Val Loss: 1.3783 | Val Acc: 35.83%
# Epoch [024/200] | LR: 0.00097 | Train Loss: 1.2936 | Train Acc: 39.17% | Val Loss: 1.3849 | Val Acc: 35.56%
# Epoch [025/200] | LR: 0.00096 | Train Loss: 1.2868 | Train Acc: 39.86% | Val Loss: 1.4177 | Val Acc: 38.06%
#  ---> 出现更高的验证集准确率 (38.06%)，已更新模型。
# Epoch [026/200] | LR: 0.00096 | Train Loss: 1.2916 | Train Acc: 39.44% | Val Loss: 1.3587 | Val Acc: 37.78%
# Epoch [027/200] | LR: 0.00096 | Train Loss: 1.2999 | Train Acc: 38.47% | Val Loss: 1.4159 | Val Acc: 39.17%
#  ---> 出现更高的验证集准确率 (39.17%)，已更新模型。
# Epoch [028/200] | LR: 0.00095 | Train Loss: 1.2832 | Train Acc: 40.14% | Val Loss: 1.4687 | Val Acc: 40.28%
#  ---> 出现更高的验证集准确率 (40.28%)，已更新模型。
# Epoch [029/200] | LR: 0.00095 | Train Loss: 1.2938 | Train Acc: 37.92% | Val Loss: 1.4240 | Val Acc: 37.22%
# Epoch [030/200] | LR: 0.00095 | Train Loss: 1.2767 | Train Acc: 42.22% | Val Loss: 1.3692 | Val Acc: 37.50%
# Epoch [031/200] | LR: 0.00094 | Train Loss: 1.2673 | Train Acc: 42.08% | Val Loss: 1.3873 | Val Acc: 39.72%
# Epoch [032/200] | LR: 0.00094 | Train Loss: 1.2585 | Train Acc: 44.17% | Val Loss: 1.5104 | Val Acc: 36.67%
# Epoch [033/200] | LR: 0.00093 | Train Loss: 1.2681 | Train Acc: 40.83% | Val Loss: 1.3630 | Val Acc: 38.61%
# Epoch [034/200] | LR: 0.00093 | Train Loss: 1.2584 | Train Acc: 43.06% | Val Loss: 1.4266 | Val Acc: 40.28%
# Epoch [035/200] | LR: 0.00093 | Train Loss: 1.2507 | Train Acc: 44.58% | Val Loss: 1.4068 | Val Acc: 39.44%
# Epoch [036/200] | LR: 0.00092 | Train Loss: 1.2566 | Train Acc: 41.11% | Val Loss: 1.3851 | Val Acc: 41.39%
#  ---> 出现更高的验证集准确率 (41.39%)，已更新模型。
# Epoch [037/200] | LR: 0.00092 | Train Loss: 1.2498 | Train Acc: 41.25% | Val Loss: 1.4773 | Val Acc: 37.22%
# Epoch [038/200] | LR: 0.00091 | Train Loss: 1.2633 | Train Acc: 42.22% | Val Loss: 1.3387 | Val Acc: 40.00%
# Epoch [039/200] | LR: 0.00091 | Train Loss: 1.2190 | Train Acc: 46.67% | Val Loss: 1.3879 | Val Acc: 40.00%
# Epoch [040/200] | LR: 0.00091 | Train Loss: 1.2339 | Train Acc: 45.56% | Val Loss: 1.4633 | Val Acc: 35.28%
# Epoch [041/200] | LR: 0.00090 | Train Loss: 1.2196 | Train Acc: 46.39% | Val Loss: 1.4055 | Val Acc: 40.56%
# Epoch [042/200] | LR: 0.00090 | Train Loss: 1.2199 | Train Acc: 48.19% | Val Loss: 1.3953 | Val Acc: 39.17%
# Epoch [043/200] | LR: 0.00089 | Train Loss: 1.2115 | Train Acc: 47.36% | Val Loss: 1.3393 | Val Acc: 39.17%
# Epoch [044/200] | LR: 0.00089 | Train Loss: 1.2321 | Train Acc: 46.67% | Val Loss: 1.3372 | Val Acc: 43.33%
#  ---> 出现更高的验证集准确率 (43.33%)，已更新模型。
# Epoch [045/200] | LR: 0.00088 | Train Loss: 1.2199 | Train Acc: 47.64% | Val Loss: 1.3910 | Val Acc: 41.11%
# Epoch [046/200] | LR: 0.00088 | Train Loss: 1.2029 | Train Acc: 48.75% | Val Loss: 1.3351 | Val Acc: 38.33%
# Epoch [047/200] | LR: 0.00087 | Train Loss: 1.2043 | Train Acc: 47.50% | Val Loss: 1.4893 | Val Acc: 39.44%
# Epoch [048/200] | LR: 0.00087 | Train Loss: 1.1825 | Train Acc: 50.69% | Val Loss: 1.3352 | Val Acc: 44.17%
#  ---> 出现更高的验证集准确率 (44.17%)，已更新模型。
# Epoch [049/200] | LR: 0.00086 | Train Loss: 1.2032 | Train Acc: 50.00% | Val Loss: 1.3921 | Val Acc: 40.28%
# Epoch [050/200] | LR: 0.00086 | Train Loss: 1.1978 | Train Acc: 48.75% | Val Loss: 1.4111 | Val Acc: 40.56%
# Epoch [051/200] | LR: 0.00085 | Train Loss: 1.1948 | Train Acc: 48.19% | Val Loss: 1.3510 | Val Acc: 40.56%
# Epoch [052/200] | LR: 0.00084 | Train Loss: 1.1739 | Train Acc: 50.56% | Val Loss: 1.4838 | Val Acc: 41.11%
# Epoch [053/200] | LR: 0.00084 | Train Loss: 1.2017 | Train Acc: 48.33% | Val Loss: 1.3361 | Val Acc: 44.17%
# Epoch [054/200] | LR: 0.00083 | Train Loss: 1.1934 | Train Acc: 50.28% | Val Loss: 1.3442 | Val Acc: 42.78%
# Epoch [055/200] | LR: 0.00083 | Train Loss: 1.1578 | Train Acc: 53.06% | Val Loss: 1.3898 | Val Acc: 44.17%
# Epoch [056/200] | LR: 0.00082 | Train Loss: 1.1579 | Train Acc: 52.08% | Val Loss: 1.3505 | Val Acc: 40.83%
# Epoch [057/200] | LR: 0.00081 | Train Loss: 1.1474 | Train Acc: 52.92% | Val Loss: 1.3589 | Val Acc: 41.94%
# Epoch [058/200] | LR: 0.00081 | Train Loss: 1.1581 | Train Acc: 51.39% | Val Loss: 1.2895 | Val Acc: 41.67%
# Epoch [059/200] | LR: 0.00080 | Train Loss: 1.1426 | Train Acc: 52.36% | Val Loss: 1.3634 | Val Acc: 41.94%
# Epoch [060/200] | LR: 0.00080 | Train Loss: 1.1384 | Train Acc: 53.19% | Val Loss: 1.3348 | Val Acc: 43.06%
# Epoch [061/200] | LR: 0.00079 | Train Loss: 1.1325 | Train Acc: 55.28% | Val Loss: 1.3302 | Val Acc: 46.11%
#  ---> 出现更高的验证集准确率 (46.11%)，已更新模型。
# Epoch [062/200] | LR: 0.00078 | Train Loss: 1.1562 | Train Acc: 53.06% | Val Loss: 1.3933 | Val Acc: 44.17%
# Epoch [063/200] | LR: 0.00078 | Train Loss: 1.1464 | Train Acc: 51.67% | Val Loss: 1.4015 | Val Acc: 38.89%
# Epoch [064/200] | LR: 0.00077 | Train Loss: 1.1330 | Train Acc: 54.44% | Val Loss: 1.3781 | Val Acc: 44.72%
# Epoch [065/200] | LR: 0.00076 | Train Loss: 1.1409 | Train Acc: 52.92% | Val Loss: 1.3853 | Val Acc: 42.22%
# Epoch [066/200] | LR: 0.00076 | Train Loss: 1.1518 | Train Acc: 55.56% | Val Loss: 1.3706 | Val Acc: 42.22%
# Epoch [067/200] | LR: 0.00075 | Train Loss: 1.1249 | Train Acc: 54.17% | Val Loss: 1.3129 | Val Acc: 45.83%
# Epoch [068/200] | LR: 0.00074 | Train Loss: 1.1400 | Train Acc: 54.44% | Val Loss: 1.3429 | Val Acc: 43.89%
# Epoch [069/200] | LR: 0.00074 | Train Loss: 1.1230 | Train Acc: 55.00% | Val Loss: 1.4143 | Val Acc: 39.17%
# Epoch [070/200] | LR: 0.00073 | Train Loss: 1.1184 | Train Acc: 54.17% | Val Loss: 1.3640 | Val Acc: 42.78%
# Epoch [071/200] | LR: 0.00072 | Train Loss: 1.1203 | Train Acc: 52.50% | Val Loss: 1.3545 | Val Acc: 42.22%
# Epoch [072/200] | LR: 0.00072 | Train Loss: 1.1079 | Train Acc: 54.86% | Val Loss: 1.3375 | Val Acc: 45.56%
# Epoch [073/200] | LR: 0.00071 | Train Loss: 1.1272 | Train Acc: 54.31% | Val Loss: 1.4164 | Val Acc: 43.33%
# Epoch [074/200] | LR: 0.00070 | Train Loss: 1.0912 | Train Acc: 57.22% | Val Loss: 1.3369 | Val Acc: 48.33%
#  ---> 出现更高的验证集准确率 (48.33%)，已更新模型。
# Epoch [075/200] | LR: 0.00069 | Train Loss: 1.1097 | Train Acc: 56.81% | Val Loss: 1.3607 | Val Acc: 42.22%
# Epoch [076/200] | LR: 0.00069 | Train Loss: 1.1142 | Train Acc: 56.11% | Val Loss: 1.3494 | Val Acc: 43.89%
# Epoch [077/200] | LR: 0.00068 | Train Loss: 1.0979 | Train Acc: 57.08% | Val Loss: 1.3469 | Val Acc: 46.67%
# Epoch [078/200] | LR: 0.00067 | Train Loss: 1.0959 | Train Acc: 58.33% | Val Loss: 1.3492 | Val Acc: 44.17%
# Epoch [079/200] | LR: 0.00067 | Train Loss: 1.0791 | Train Acc: 58.61% | Val Loss: 1.3436 | Val Acc: 48.33%
# Epoch [080/200] | LR: 0.00066 | Train Loss: 1.0898 | Train Acc: 57.22% | Val Loss: 1.3322 | Val Acc: 45.83%
# Epoch [081/200] | LR: 0.00065 | Train Loss: 1.0972 | Train Acc: 55.83% | Val Loss: 1.3001 | Val Acc: 48.06%
# Epoch [082/200] | LR: 0.00064 | Train Loss: 1.0630 | Train Acc: 59.58% | Val Loss: 1.3529 | Val Acc: 42.78%
# Epoch [083/200] | LR: 0.00064 | Train Loss: 1.0696 | Train Acc: 58.19% | Val Loss: 1.4291 | Val Acc: 45.56%
# Epoch [084/200] | LR: 0.00063 | Train Loss: 1.0775 | Train Acc: 58.61% | Val Loss: 1.3272 | Val Acc: 46.67%
# Epoch [085/200] | LR: 0.00062 | Train Loss: 1.0592 | Train Acc: 60.14% | Val Loss: 1.4205 | Val Acc: 46.67%
# Epoch [086/200] | LR: 0.00061 | Train Loss: 1.0474 | Train Acc: 59.72% | Val Loss: 1.3267 | Val Acc: 44.72%
# Epoch [087/200] | LR: 0.00061 | Train Loss: 1.0605 | Train Acc: 59.03% | Val Loss: 1.3756 | Val Acc: 44.44%
# Epoch [088/200] | LR: 0.00060 | Train Loss: 1.0683 | Train Acc: 59.03% | Val Loss: 1.3695 | Val Acc: 46.94%
# Epoch [089/200] | LR: 0.00059 | Train Loss: 1.0602 | Train Acc: 59.03% | Val Loss: 1.3279 | Val Acc: 48.89%
#  ---> 出现更高的验证集准确率 (48.89%)，已更新模型。
# Epoch [090/200] | LR: 0.00058 | Train Loss: 1.0695 | Train Acc: 58.75% | Val Loss: 1.3678 | Val Acc: 43.89%
# Epoch [091/200] | LR: 0.00057 | Train Loss: 1.0851 | Train Acc: 58.75% | Val Loss: 1.3685 | Val Acc: 48.89%
# Epoch [092/200] | LR: 0.00057 | Train Loss: 1.0324 | Train Acc: 61.53% | Val Loss: 1.4013 | Val Acc: 40.83%
# Epoch [093/200] | LR: 0.00056 | Train Loss: 1.0300 | Train Acc: 61.81% | Val Loss: 1.3389 | Val Acc: 45.00%
# Epoch [094/200] | LR: 0.00055 | Train Loss: 1.0310 | Train Acc: 63.47% | Val Loss: 1.3883 | Val Acc: 45.83%
# Epoch [095/200] | LR: 0.00054 | Train Loss: 1.0216 | Train Acc: 63.19% | Val Loss: 1.3588 | Val Acc: 44.72%
# Epoch [096/200] | LR: 0.00054 | Train Loss: 1.0327 | Train Acc: 61.25% | Val Loss: 1.3704 | Val Acc: 49.17%
#  ---> 出现更高的验证集准确率 (49.17%)，已更新模型。
# Epoch [097/200] | LR: 0.00053 | Train Loss: 1.0113 | Train Acc: 60.69% | Val Loss: 1.3246 | Val Acc: 47.78%
# Epoch [098/200] | LR: 0.00052 | Train Loss: 1.0356 | Train Acc: 60.97% | Val Loss: 1.3561 | Val Acc: 49.17%
# Epoch [099/200] | LR: 0.00051 | Train Loss: 1.0428 | Train Acc: 60.28% | Val Loss: 1.3932 | Val Acc: 48.06%
# Epoch [100/200] | LR: 0.00050 | Train Loss: 1.0550 | Train Acc: 60.83% | Val Loss: 1.3112 | Val Acc: 45.28%
# Epoch [101/200] | LR: 0.00050 | Train Loss: 1.0300 | Train Acc: 61.11% | Val Loss: 1.3369 | Val Acc: 48.89%
# Epoch [102/200] | LR: 0.00049 | Train Loss: 1.0143 | Train Acc: 65.56% | Val Loss: 1.3779 | Val Acc: 46.11%
# Epoch [103/200] | LR: 0.00048 | Train Loss: 0.9958 | Train Acc: 64.17% | Val Loss: 1.3766 | Val Acc: 46.94%
# Epoch [104/200] | LR: 0.00047 | Train Loss: 1.0067 | Train Acc: 63.75% | Val Loss: 1.4305 | Val Acc: 46.11%
# Epoch [105/200] | LR: 0.00047 | Train Loss: 1.0226 | Train Acc: 61.53% | Val Loss: 1.3476 | Val Acc: 47.22%
# Epoch [106/200] | LR: 0.00046 | Train Loss: 1.0179 | Train Acc: 62.08% | Val Loss: 1.3190 | Val Acc: 47.78%
# Epoch [107/200] | LR: 0.00045 | Train Loss: 0.9993 | Train Acc: 63.47% | Val Loss: 1.3861 | Val Acc: 50.83%
#  ---> 出现更高的验证集准确率 (50.83%)，已更新模型。
# Epoch [108/200] | LR: 0.00044 | Train Loss: 1.0207 | Train Acc: 63.06% | Val Loss: 1.2980 | Val Acc: 50.28%
# Epoch [109/200] | LR: 0.00044 | Train Loss: 1.0190 | Train Acc: 63.19% | Val Loss: 1.3719 | Val Acc: 46.94%
# Epoch [110/200] | LR: 0.00043 | Train Loss: 1.0168 | Train Acc: 61.53% | Val Loss: 1.3710 | Val Acc: 49.17%
# Epoch [111/200] | LR: 0.00042 | Train Loss: 1.0132 | Train Acc: 64.17% | Val Loss: 1.3832 | Val Acc: 50.00%
# Epoch [112/200] | LR: 0.00041 | Train Loss: 0.9981 | Train Acc: 63.75% | Val Loss: 1.3827 | Val Acc: 48.06%
# Epoch [113/200] | LR: 0.00040 | Train Loss: 1.0206 | Train Acc: 60.00% | Val Loss: 1.4153 | Val Acc: 48.89%
# Epoch [114/200] | LR: 0.00040 | Train Loss: 0.9999 | Train Acc: 64.44% | Val Loss: 1.3439 | Val Acc: 49.44%
# Epoch [115/200] | LR: 0.00039 | Train Loss: 0.9939 | Train Acc: 65.56% | Val Loss: 1.3267 | Val Acc: 47.50%
# Epoch [116/200] | LR: 0.00038 | Train Loss: 1.0041 | Train Acc: 64.03% | Val Loss: 1.3905 | Val Acc: 48.33%
# Epoch [117/200] | LR: 0.00037 | Train Loss: 0.9926 | Train Acc: 64.31% | Val Loss: 1.3518 | Val Acc: 50.56%
# Epoch [118/200] | LR: 0.00037 | Train Loss: 0.9947 | Train Acc: 63.89% | Val Loss: 1.3581 | Val Acc: 47.50%
# Epoch [119/200] | LR: 0.00036 | Train Loss: 1.0065 | Train Acc: 65.56% | Val Loss: 1.3872 | Val Acc: 47.50%
# Epoch [120/200] | LR: 0.00035 | Train Loss: 0.9868 | Train Acc: 66.11% | Val Loss: 1.3612 | Val Acc: 48.06%
# Epoch [121/200] | LR: 0.00034 | Train Loss: 0.9762 | Train Acc: 66.39% | Val Loss: 1.3935 | Val Acc: 49.17%
# Epoch [122/200] | LR: 0.00034 | Train Loss: 0.9970 | Train Acc: 61.81% | Val Loss: 1.3759 | Val Acc: 49.44%
# Epoch [123/200] | LR: 0.00033 | Train Loss: 0.9815 | Train Acc: 65.69% | Val Loss: 1.3659 | Val Acc: 49.72%
# Epoch [124/200] | LR: 0.00032 | Train Loss: 0.9701 | Train Acc: 66.81% | Val Loss: 1.3618 | Val Acc: 50.28%
# Epoch [125/200] | LR: 0.00032 | Train Loss: 0.9811 | Train Acc: 64.17% | Val Loss: 1.3753 | Val Acc: 50.00%
# Epoch [126/200] | LR: 0.00031 | Train Loss: 0.9632 | Train Acc: 65.69% | Val Loss: 1.4095 | Val Acc: 46.67%
# Epoch [127/200] | LR: 0.00030 | Train Loss: 0.9879 | Train Acc: 65.28% | Val Loss: 1.3602 | Val Acc: 50.00%
#
# Triggered Early Stopping at Epoch 127!
#
# ----------------------------------------
# Final Best Val Accuracy: 50.83%
# 训练成功结束！最佳模型已保存至: model_checkpoints/BCIC2A_best_model_acc50.83.pth

# %% [markdown]
# ## 6) 训练过程可视化

# %%
plt.figure(figsize=(12, 5))

# 绘制 Loss 曲线
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss", marker='o', markersize=3)
plt.plot(val_losses, label="Val Loss", marker='o', markersize=3)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train / Val Loss Curve")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# 绘制 Accuracy 曲线
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label="Train Accuracy", marker='o', markersize=3, color='blue')
plt.plot(val_accuracies, label="Val Accuracy", marker='o', markersize=3, color='green')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train / Val Accuracy Curve") 
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7) 测试集推理与结果生成
# 执行测试推理前，将回载上面跑出来的“最佳验证集权重”，以此来产出最终提交的结果。

# %%
# -------------------------
# 加载最佳模型权重
# -------------------------
print(f"Loading best model from {best_model_path} for testing...")
model.load_state_dict(torch.load(best_model_path, map_location=device, weights_only=True))
model.eval()

output_path = f'course_project/{DATA_NAME}/{DATA_NAME}.txt'
all_test_labels = []

with torch.no_grad():
    for test_data in test_loader:  # test_loader 已经是 shuffle=False
        test_data = test_data.to(device)
        test_output = model(test_data)
        test_pred = torch.argmax(test_output, dim=1)
        all_test_labels.extend(test_pred.cpu().tolist())

# 保存 test 预测标签（每行一个数字）
with open(output_path, "w", encoding="utf-8") as f:
    for label in all_test_labels:
        f.write(f"{int(label)}\n")

print(f"Saved {len(all_test_labels)} labels to: {output_path}")
